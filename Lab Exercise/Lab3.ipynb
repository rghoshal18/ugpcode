# %%
import numpy as np
import pandas as pd
import urllib
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
k=np.loadtxt('a.txt',skiprows=34)
#x=pd.DataFrame(k,columns=['Year','Month','Monthly-anamoly','Uncertanity','Annual-anamoly','Uncertanity','Five-year-anamoly','Uncertanity','Ten-year-anamoly','Uncertanity','Twelve-year-anamoly','Uncertanity','Twenty-year-anamoly','Uncertanity'])
x=pd.DataFrame(k,columns='Year Month Monthly-anamoly Monthly-Uncertanity Annual-anamoly Annual-Uncertanity Five-year-anamoly Five-year-Uncertanity Ten-year-anamoly Ten-year-Uncertanity Twenty-year-anamoly Twenty-year-Uncertanity'.split())
x
# Out:
#         Year  Month  Monthly-anamoly  Monthly-Uncertanity  Annual-anamoly  \
# 0     1750.0    1.0           -0.221                3.204          -0.679
# 1     1750.0    2.0           -1.624                3.451          -0.618
# 2     1750.0    3.0           -0.524                2.970          -0.628
# 3     1750.0    4.0            0.124                2.184          -0.651
# 4     1750.0    5.0           -1.072                2.773          -0.988
# 5     1750.0    6.0           -0.702                1.163          -0.967
# 6     1750.0    7.0            0.180                2.254          -1.028
# 7     1750.0    8.0            0.974                1.406          -1.150
# 8     1750.0    9.0           -0.243                1.895          -1.111
# 9     1750.0   10.0           -1.603                2.559          -1.180
# 10    1750.0   11.0           -4.111                2.197          -1.210
# 11    1750.0   12.0           -2.771                3.472          -1.268
# ...

# %%
y=x.drop(['Year','Month'],axis=1)

# %%
y.max()
# Out:
# Monthly-anamoly            5.814
# Monthly-Uncertanity        7.594
# Annual-anamoly             1.508
# Annual-Uncertanity         2.365
# Five-year-anamoly          1.267
# Five-year-Uncertanity      1.312
# Ten-year-anamoly           1.111
# Ten-year-Uncertanity       1.044
# Twenty-year-anamoly        0.982
# Twenty-year-Uncertanity    0.873
# dtype: float64

# %%
y.mean()
# Out:
# Monthly-anamoly           -0.284994
# Monthly-Uncertanity        0.893304
# Annual-anamoly            -0.288017
# Annual-Uncertanity         0.423061
# Five-year-anamoly         -0.296867
# Five-year-Uncertanity      0.281262
# Ten-year-anamoly          -0.308554
# Ten-year-Uncertanity       0.242006
# Twenty-year-anamoly       -0.323394
# Twenty-year-Uncertanity    0.206020
# dtype: float64

# %%
y.std()
# Out:
# Monthly-anamoly            0.933989
# Monthly-Uncertanity        1.045452
# Annual-anamoly             0.602464
# Annual-Uncertanity         0.467774
# Five-year-anamoly          0.527158
# Five-year-Uncertanity      0.304041
# Ten-year-anamoly           0.489171
# Ten-year-Uncertanity       0.255760
# Twenty-year-anamoly        0.429370
# Twenty-year-Uncertanity    0.211898
# dtype: float64

# %%
plt.plot(x['new'],x['Monthly-anamoly'], 'r') # 'r' is the color red
plt.xlabel('Year')
plt.ylabel('Monthly-anamoly')
plt.title('Time Series plot of Monthly Anamoly')
plt.show()

# %%
x['new']=x['Year'].map(str)+'-'+x['Month'].map(str)

# %%
plt.plot(x['new'],x['Annual-anamoly'], 'r') # 'r' is the color red
plt.xlabel('Year')
plt.ylabel('Annual-anamoly')
plt.title('Time Series plot of Annual Anamoly')
plt.show()

# %%
plt.plot(x['new'],x['Ten-year-anamoly'], 'r') # 'r' is the color red
plt.xlabel('Year')
plt.ylabel('Ten-year-anamoly')
plt.title('Time Series plot of Ten-year-Anamoly')
plt.show()

# %%
plt.plot(x['new'],x['Twenty-year-anamoly'], 'r') # 'r' is the color red
plt.xlabel('Year')
plt.ylabel('Twenty-year-anamoly')
plt.title('Time Series plot of Twenty-year-Anamoly')
plt.show()

# %%
plt.plot(x['new'],x['Twenty-year-Uncertanity'], 'r') # 'r' is the color red
plt.xlabel('Year')
plt.ylabel('Twenty-year-anamoly')
plt.title('Time Series plot of Twenty-year-Anamoly')
plt.show()

# %%
dy = 0.8
plt.errorbar(x['new'], y['Monthly-anamoly'],yerr=dy, fmt='.k')
plt.xlabel('Year')
plt.ylabel('Monthly-anamoly')
plt.title('Time Series plot of Monthly-Anamoly')
plt.show()

# %%
dy = 0.7
plt.errorbar(x['new'], y['Monthly-Uncertanity'],yerr=dy, fmt='.k')
plt.xlabel('Year')
plt.ylabel('Monthly-Uncertanity')
plt.title('Time Series plot of Monthly-Uncertanity')
plt.show()

# %%
plt.plot(x['Year'],x['Monthly-anamoly'], 'r') # 'r' is the color red
plt.xlabel('Year')
plt.ylabel('Monthly-anamoly')
plt.title('Time Series plot of Monthly Anamoly')
plt.show()

# %%
plt.scatter(x['Year'],x['data:image/png;base64,...-anamoly'], marker='o');
plt.xlabel('Year')
plt.ylabel('Monthly-anamoly')
plt.title('Time Series plot of Monthly Anamoly')
plt.show()

# %%
k2=np.loadtxt('saw.txt',skiprows=68)
y=pd.DataFrame(k2,columns='Year Month Monthly-anamoly Monthly-Uncertanity Annual-anamoly Annual-Uncertanity Five-year-anamoly Five-year-Uncertanity Ten-year-anamoly Ten-year-Uncertanity Twenty-year-anamoly Twenty-year-Uncertanity'.split())
y
# Out:
#         Year  Month  Monthly-anamoly  Monthly-Uncertanity  Annual-anamoly  \
# 0     1796.0    1.0            0.167                2.331             NaN
# 1     1796.0    2.0           -0.551                1.807             NaN
# 2     1796.0    3.0           -1.932                2.512          -0.444
# 3     1796.0    4.0           -0.584                1.987          -0.353
# 4     1796.0    5.0            0.123                1.797          -0.333
# 5     1796.0    6.0           -0.005                3.099          -0.445
# 6     1796.0    7.0            0.184                2.367          -0.261
# 7     1796.0    8.0            0.570                2.780          -0.040
# 8     1796.0    9.0           -0.138                3.170           0.004
# 9     1796.0   10.0           -0.298                1.633          -0.069
# 10    1796.0   11.0           -0.585                2.752          -0.140
# 11    1796.0   12.0           -2.290                3.581          -0.111
# ...

# %%
ax3D = fig.add_subplot(111, projection='3d')
ax3D.scatter(x['Monthly-anamoly',y['Monthly-anamoly',x['Year'], s=10, c=col, marker='o')  ;
plt.xlabel('Global')
plt.ylabel('Kanpur')
plt.zlabel('Year')
plt.title('Time Series plot of kanpur and global data')
plt.show()
# Out:
#   File "<ipython-input-15-cbffcdc05fa5>", line 2
#     ax3D.scatter(x['Monthly-anamoly',y['Monthly-anamoly',x['Year'], s=10, c=col, marker='o')  ;
#                                                                      ^
# SyntaxError: invalid syntax
