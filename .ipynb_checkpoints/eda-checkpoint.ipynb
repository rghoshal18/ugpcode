# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
# df1 = pd.read_csv("/media/rghoshal/D4A6E10AA6E0EE44/UGP/datasets/data.csv",index_col = 0)
# df2 = pd.read_csv("/media/rghoshal/D4A6E10AA6E0EE44/UGP/datasets/data2.csv",index_col = 0)
# df3 = pd.read_csv("/media/rghoshal/D4A6E10AA6E0EE44/UGP/datasets/data3.csv",index_col = 0)
# df = [df1 , df3]
# df = pd.concat(df)
# df = df.reset_index(drop = True)
# df.to_csv("/media/rghoshal/D4A6E10AA6E0EE44/UGP/datasets/data.csv")

df = pd.read_csv("/media/rghoshal/D4A6E10AA6E0EE44/UGP/datasets/data.csv",index_col = 0)
df
# Out:
#               time    lat     lon  sla    precip  enso
# 0       1993-01-15  -1.25   43.75  0.0  1.647459  0.09
# 1       1993-01-15  -1.25   46.25  0.0  2.560627  0.09
# 2       1993-01-15  -1.25   48.75  0.0  2.937700  0.09
# 3       1993-01-15  -1.25   51.25  0.0  3.374984  0.09
# 4       1993-01-15  -1.25   53.75  0.0  3.629688  0.09
# ...            ...    ...     ...  ...       ...   ...
# 162235  2018-12-15  46.25   96.25  0.0  0.153215  0.81
# 162236  2018-12-15  46.25   98.75  0.0  0.059969  0.81
# 162237  2018-12-15  46.25  101.25  0.0  0.099445  0.81
# 162238  2018-12-15  46.25  103.75  0.0  0.079326  0.81
# 162239  2018-12-15  46.25  106.25  0.0  0.054988  0.81
#
# [162240 rows x 6 columns]

# %%
df.dtypes
# Out:
# time       object
# lat       float64
# lon       float64
# sla       float64
# precip    float64
# enso      float64
# dtype: object

# %%
df.shape
# Out:
# (162240, 6)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [time, lat, lon, sla, precip, enso]
# Index: []

# %%
df.count()
# Out:
# time      162240
# lat       162240
# lon       162240
# sla        78936
# precip    162240
# enso      162240
# dtype: int64

# %%
df.isnull().sum()
# Out:
# time          0
# lat           0
# lon           0
# sla       83304
# precip        0
# enso          0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x = pd.DatetimeIndex(df['time']).month , y = "sla",data =df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='sla'>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x = pd.DatetimeIndex(df['time']).month , y = "precip",data =df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='precip'>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x = pd.DatetimeIndex(df['time']).year , y = "enso",data =df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='enso'>

# %%
Q1 = df.quantile(.25)
Q3 = df.quantile(.75)
IQR = Q3 - Q1
IQR
# Out:
# lat       23.750000
# lon       32.500000
# sla        0.062801
# precip     3.190672
# enso       1.032500
# dtype: float64

# %%
df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
#               time    lat     lon  sla    precip  enso
# 0       1993-01-15  -1.25   43.75  0.0  1.647459  0.09
# 1       1993-01-15  -1.25   46.25  0.0  2.560627  0.09
# 2       1993-01-15  -1.25   48.75  0.0  2.937700  0.09
# 3       1993-01-15  -1.25   51.25  0.0  3.374984  0.09
# 4       1993-01-15  -1.25   53.75  0.0  3.629688  0.09
# ...            ...    ...     ...  ...       ...   ...
# 162235  2018-12-15  46.25   96.25  0.0  0.153215  0.81
# 162236  2018-12-15  46.25   98.75  0.0  0.059969  0.81
# 162237  2018-12-15  46.25  101.25  0.0  0.099445  0.81
# 162238  2018-12-15  46.25  103.75  0.0  0.079326  0.81
# 162239  2018-12-15  46.25  106.25  0.0  0.054988  0.81
#
# [137090 rows x 6 columns]

# %%
bhopal = df[(df['lat'] == 23.75) & (df['lon'] == 76.25 ) ]
kanpur = df[(df['lat'] == 26.25) & (df['lon'] == 81.25 ) ]
bombay = df[(df['lat'] == 18.75) & (df['lon'] == 71.25 ) ]
bhopal["month"] = pd.DatetimeIndex(bhopal['time']).month
kanpur["month"] = pd.DatetimeIndex(kanpur['time']).month
bombay["month"] = pd.DatetimeIndex(bombay['time']).month
# Out:
# /home/rghoshal/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/rghoshal/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/rghoshal/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from scipy import stats
def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2

sns.jointplot(kanpur[kanpur.month == 8]["enso"], kanpur[kanpur.month == 8]["precip"] , kind="reg", stat_func=r2)
# Out:
# /home/rghoshal/miniconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
sns.lmplot(x = "enso",y = "precip", data = kanpur , col = "month" , hue ="month" , col_wrap=4, height=3)

# %%
sns.lmplot(x = "enso",y = "precip", data = bhopal , col = "month" , hue ="month" , col_wrap=4, height=3)

# %%
sns.lmplot(x = "enso",y = "precip", data = bombay , col = "month" , hue ="month" , col_wrap=4, height=3)

# %%
np.corrcoef(kanpur[kanpur.month == 6]["enso"], kanpur[kanpur.month == 6]["precip"])
# Out:
# array([[ 1.        , -0.34026667],
#        [-0.34026667,  1.        ]])

# %%
sns.jointplot(kanpur["precip"],df.groupby("time")["sla"].mean())
